# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pymongo

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.mars_db
collection = db.articles

# %%
# URL of page to be scraped
url = 'https://mars.nasa.gov/news'

# Retrieve page with the requests module
response = requests.get(url)
# Create BeautifulSoup object
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# Retrieve the parent divs for all articles
results = soup.find_all('div', class_='media_feature_title')

# loop over results to get article data
for result in results:
    # scrape the article header 
    header = result.find('h1', class_='media_feature_title').text
    
    # scrape the article subheader
    subheader = result.find('h2', class_='article-item__subheader').text
    
    # scrape the datetime
    datetime = result.find('span', class_='article-item__date')['data-date'] 
    
    # get only the date from the datetime
    date = datetime.split('T')[0]
    
    # print article data
    print('-----------------')
    print(header)
    print(subheader)
    print(date)

    # Dictionary to be inserted into MongoDB
    post = {
        'header': header,
        'subheader': subheader,
        'date': date,
    }

    # Insert dictionary into MongoDB as a document
    collection.insert_one(post)
# Out:
# -----------------
# Inside look at Carolina Hurricanes
# Relying on maturing core, recent playoff exprience to make deep run this season
# 2020-11-21
# -----------------
# Top goalie in NHL in 3 seasons debated
# Shesterkin, Vasilevskiy, Hellebuyck, Hart among favorites of NHL.com writers
# 2020-11-21
# -----------------
# Three questions facing Carolina Hurricanes
# Mrazek, Reimer potential in goal, Hamilton's expiring contract among concerns
# 2020-11-21
# -----------------
# Top prospects for Carolina Hurricanes
# Bean could make opening roster; Bokk to play in North America
# 2020-11-21
# -----------------
# Thornton will spark Maple Leafs, GM of Switzerland team says: report
# 41-year-old center leads NHL active players in points, assists
# 2020-11-20
# -----------------
# Reverse Retro alternate jerseys for all 31 teams unveiled by NHL, adidas
# Will be worn multiple times this season; available for purchase starting Dec. 1
# 2020-11-16
# -----------------
# Khudobin expected to be ready for training camp for Stars after sugery
# Goalie had nerve issue in arm; Bishop, Seguin recovering
# 2020-11-20
# -----------------
# Carolina Hurricanes key statistics
# Hamilton expected to drive puck possession; Mrazek should boost save percentage at 5-on-5
# 2020-11-21
# -----------------
# Askarov named to Russia World Junior Championship selection camp
# Goalie, No. 11 pick by Predators, one of four first-rounders from 2020 Draft on roster
# 2020-11-20
# -----------------
# Fantasy goalie tandem rankings for 2020-21
# NHL.com lists best duos at position to consider handcuffing in standard draft
# 2020-11-19
# -----------------
# NHL Free Agent Tracker
# Complete list of signings by team, available players
# 2020-11-13
# -----------------
# Lightning trainer, Star Wars fanatic enjoys Stanley Cup with Baby Yoda
# Mike Poirier wore Darth Vader helmet for this day at home with trophy
# 2020-11-20
# -----------------
# Byfield won't join Kings until after playing for Canada at World Juniors
# Forward would stay at tournament scheduled through Jan. 5
# 2020-11-19
# -----------------
# Thomas making adjustments on, off ice as pro career starts in Germany
# Kings forward prospect using opportunity with Eisbaren Berlin to get ready for NHL
# 2020-11-20
# -----------------
# Carolina Hurricanes fantasy preview for 2020-21
# Aho anchors potent first line; Teravainen benefits from exposure to Svechnikov
# 2020-11-16
# -----------------
# 2020-21 NHL Trade Tracker
# Official deals since Oct. 1, 2020
# 2020-10-12
# -----------------
# Tkachuks pay visit to Blues Warrior Hockey program to support veterans
# Keith, Matthew and Brady stop by for skate, pictures and autographs
# 2020-11-20
# -----------------
# Inside look at Calgary Flames
# Hope additions of Markstrom, Tanev to core group can lead to postseason success
# 2020-11-20
# -----------------
# Theodore of Golden Knights honors grandmother with fund to fight cancer
# Defenseman reflects on own recovery, urges importance of early detection
# 2020-11-19
# -----------------
# Panthers new assistant GM Peterson featured on NHL @TheRink podcast
# Rosen, Roarke also discuss coaching with LeClair, Reverse Retro jerseys in latest episode
# 2020-11-19
# -----------------
# CN Tower lights up lavender for Hockey Fights Cancer Month
# Legendary Toronto landmark changes colors for NHL initiative
# 2020-11-18
# -----------------
# Holtby, tortoises finally make it across U.S.-Canada border
# Canucks goalie was trying to cross with pets but didn't have right paperwork
# 2020-11-19
# -----------------
# NHL adds human touch to campaign against cancer
# Leaguewide social moments, storytelling driving awareness of work to combat disease
# 2020-11-19
# -----------------
# Mailbag: Ovechkin's chase of Gretzky, Reverse Retro jerseys
# NHL.com's Tom Gulitti answers weekly questions
# 2020-11-18
# -----------------
# NHL Fantasy on Ice season preview podcasts
# Breakouts/bounce-backs, sleepers, rookies/keepers, mock draft, offseason moves
# 2020-11-18
# -----------------
# NHL schedule could combine hub format, home arenas in 2020-21
# League seeking flexibility planning season amid coronavirus pandemic
# 2020-11-13
# -----------------
# Blue Jackets confident restricted free agent Dubois will sign before camp
# GM preaching patience but '100 percent sure' contract will get done
# 2020-11-18
# -----------------
# Power, Raty among top 2021 prospects discussed on NHL Draft Class podcast
# Latest episode features Central Scouting on top players, changes to process
# 2020-11-18
# -----------------
# Stuetzle, No. 3 pick in 2020 Draft by Senators, named to Germany WJC team
# Forward recovering from arm surgery, had five assists in tournament last year
# 2020-11-18
# -----------------
# Nov. 21: Jagr becomes NHL's all-time top European goal scorer
# Plus: Overtime ended because of World War II; Rangers set team single-game scoring mark
# 2020-11-21

# %%
# Display the MongoDB records created above
articles = db.articles.find()
for article in articles:
    print(article)
# Out:
# {'_id': ObjectId('5fb89e2e87048b95532505db'), 'header': 'Inside look at Carolina Hurricanes', 'subheader': 'Relying on maturing core, recent playoff exprience to make deep run this season', 'date': '2020-11-21'}
# {'_id': ObjectId('5fb89e2e87048b95532505dc'), 'header': 'Top goalie in NHL in 3 seasons debated', 'subheader': 'Shesterkin, Vasilevskiy, Hellebuyck, Hart among favorites of NHL.com writers', 'date': '2020-11-21'}
# {'_id': ObjectId('5fb89e2e87048b95532505dd'), 'header': 'Three questions facing Carolina Hurricanes', 'subheader': "Mrazek, Reimer potential in goal, Hamilton's expiring contract among concerns", 'date': '2020-11-21'}
# {'_id': ObjectId('5fb89e2e87048b95532505de'), 'header': 'Top prospects for Carolina Hurricanes', 'subheader': 'Bean could make opening roster; Bokk to play in North America', 'date': '2020-11-21'}
# {'_id': ObjectId('5fb89e2e87048b95532505df'), 'header': 'Thornton will spark Maple Leafs, GM of Switzerland team says: report', 'subheader': '41-year-old center leads NHL active players in points, assists', 'date': '2020-11-20'}
# {'_id': ObjectId('5fb89e2e87048b95532505e0'), 'header': 'Reverse Retro alternate jerseys for all 31 teams unveiled by NHL, adidas', 'subheader': 'Will be worn multiple times this season; available for purchase starting Dec. 1', 'date': '2020-11-16'}
# {'_id': ObjectId('5fb89e2e87048b95532505e1'), 'header': 'Khudobin expected to be ready for training camp for Stars after sugery', 'subheader': 'Goalie had nerve issue in arm; Bishop, Seguin recovering', 'date': '2020-11-20'}
# {'_id': ObjectId('5fb89e2e87048b95532505e2'), 'header': 'Carolina Hurricanes key statistics', 'subheader': 'Hamilton expected to drive puck possession; Mrazek should boost save percentage at 5-on-5', 'date': '2020-11-21'}
# {'_id': ObjectId('5fb89e2e87048b95532505e3'), 'header': 'Askarov named to Russia World Junior Championship selection camp', 'subheader': 'Goalie, No. 11 pick by Predators, one of four first-rounders from 2020 Draft on roster', 'date': '2020-11-20'}
# {'_id': ObjectId('5fb89e2e87048b95532505e4'), 'header': 'Fantasy goalie tandem rankings for 2020-21', 'subheader': 'NHL.com lists best duos at position to consider handcuffing in standard draft', 'date': '2020-11-19'}
# {'_id': ObjectId('5fb89e2e87048b95532505e5'), 'header': 'NHL Free Agent Tracker', 'subheader': 'Complete list of signings by team, available players', 'date': '2020-11-13'}
# {'_id': ObjectId('5fb89e2e87048b95532505e6'), 'header': 'Lightning trainer, Star Wars fanatic enjoys Stanley Cup with Baby Yoda', 'subheader': 'Mike Poirier wore Darth Vader helmet for this day at home with trophy', 'date': '2020-11-20'}
# {'_id': ObjectId('5fb89e2e87048b95532505e7'), 'header': "Byfield won't join Kings until after playing for Canada at World Juniors", 'subheader': 'Forward would stay at tournament scheduled through Jan. 5', 'date': '2020-11-19'}
# {'_id': ObjectId('5fb89e2e87048b95532505e8'), 'header': 'Thomas making adjustments on, off ice as pro career starts in Germany', 'subheader': 'Kings forward prospect using opportunity with Eisbaren Berlin to get ready for NHL', 'date': '2020-11-20'}
# {'_id': ObjectId('5fb89e2e87048b95532505e9'), 'header': 'Carolina Hurricanes fantasy preview for 2020-21', 'subheader': 'Aho anchors potent first line; Teravainen benefits from exposure to Svechnikov', 'date': '2020-11-16'}
# {'_id': ObjectId('5fb89e2e87048b95532505ea'), 'header': '2020-21 NHL Trade Tracker', 'subheader': 'Official deals since Oct. 1, 2020', 'date': '2020-10-12'}
# {'_id': ObjectId('5fb89e2e87048b95532505eb'), 'header': 'Tkachuks pay visit to Blues Warrior Hockey program to support veterans', 'subheader': 'Keith, Matthew and Brady stop by for skate, pictures and autographs', 'date': '2020-11-20'}
# {'_id': ObjectId('5fb89e2e87048b95532505ec'), 'header': 'Inside look at Calgary Flames', 'subheader': 'Hope additions of Markstrom, Tanev to core group can lead to postseason success', 'date': '2020-11-20'}
# {'_id': ObjectId('5fb89e2e87048b95532505ed'), 'header': 'Theodore of Golden Knights honors grandmother with fund to fight cancer', 'subheader': 'Defenseman reflects on own recovery, urges importance of early detection', 'date': '2020-11-19'}
# {'_id': ObjectId('5fb89e2e87048b95532505ee'), 'header': 'Panthers new assistant GM Peterson featured on NHL @TheRink podcast', 'subheader': 'Rosen, Roarke also discuss coaching with LeClair, Reverse Retro jerseys in latest episode', 'date': '2020-11-19'}
# {'_id': ObjectId('5fb89e2e87048b95532505ef'), 'header': 'CN Tower lights up lavender for Hockey Fights Cancer Month', 'subheader': 'Legendary Toronto landmark changes colors for NHL initiative', 'date': '2020-11-18'}
# {'_id': ObjectId('5fb89e2e87048b95532505f0'), 'header': 'Holtby, tortoises finally make it across U.S.-Canada border', 'subheader': "Canucks goalie was trying to cross with pets but didn't have right paperwork", 'date': '2020-11-19'}
# {'_id': ObjectId('5fb89e2e87048b95532505f1'), 'header': 'NHL adds human touch to campaign against cancer', 'subheader': 'Leaguewide social moments, storytelling driving awareness of work to combat disease', 'date': '2020-11-19'}
# {'_id': ObjectId('5fb89e2e87048b95532505f2'), 'header': "Mailbag: Ovechkin's chase of Gretzky, Reverse Retro jerseys", 'subheader': "NHL.com's Tom Gulitti answers weekly questions", 'date': '2020-11-18'}
# {'_id': ObjectId('5fb89e2e87048b95532505f3'), 'header': 'NHL Fantasy on Ice season preview podcasts', 'subheader': 'Breakouts/bounce-backs, sleepers, rookies/keepers, mock draft, offseason moves', 'date': '2020-11-18'}
# {'_id': ObjectId('5fb89e2e87048b95532505f4'), 'header': 'NHL schedule could combine hub format, home arenas in 2020-21', 'subheader': 'League seeking flexibility planning season amid coronavirus pandemic', 'date': '2020-11-13'}
# {'_id': ObjectId('5fb89e2e87048b95532505f5'), 'header': 'Blue Jackets confident restricted free agent Dubois will sign before camp', 'subheader': "GM preaching patience but '100 percent sure' contract will get done", 'date': '2020-11-18'}
# {'_id': ObjectId('5fb89e2e87048b95532505f6'), 'header': 'Power, Raty among top 2021 prospects discussed on NHL Draft Class podcast', 'subheader': 'Latest episode features Central Scouting on top players, changes to process', 'date': '2020-11-18'}
# {'_id': ObjectId('5fb89e2e87048b95532505f7'), 'header': 'Stuetzle, No. 3 pick in 2020 Draft by Senators, named to Germany WJC team', 'subheader': 'Forward recovering from arm surgery, had five assists in tournament last year', 'date': '2020-11-18'}
# {'_id': ObjectId('5fb89e2e87048b95532505f8'), 'header': "Nov. 21: Jagr becomes NHL's all-time top European goal scorer", 'subheader': 'Plus: Overtime ended because of World War II; Rangers set team single-game scoring mark', 'date': '2020-11-21'}
