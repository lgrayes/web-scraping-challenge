# %%
# !pip install webdriver_manager

# %%
# Import BeautifulSoup
from bs4 import BeautifulSoup
from splinter import Browser
import requests
import re
from webdriver_manager.chrome import ChromeDriverManager

# !which chromedriver

executable_path = {"executable_path": ChromeDriverManager().install()}
# executable_path = {'executable_path': '/Applications/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-64-0489de6358c5> in <module>()
#       4 import requests
#       5 import re
# ----> 6 import document
#       7 from webdriver_manager.chrome import ChromeDriverManager
#       8
#
# ModuleNotFoundError: No module named 'document'

# %%
# Visit the following URL
url = "https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars"
browser.visit(url)

# %%
# Retrieve page with the requests module
response = requests.get(url)
# Create BeautifulSoup object
soup = BeautifulSoup(response.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if IE 9]> <html class="no-js ie ie9" lang="en"> <![endif]-->
# <!--[if IE 8]> <html class="no-js ie ie8" lang="en"> <![endif]-->
# <html>
# <!-- START HEADER: "DEFAULT" -->
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push(
# {'gtm.start': new Date().getTime(),event:'gtm.js'}
# );var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-NLDQZ25');</script>
# <!-- End Google Tag Manager -->
# <head>
# <meta charset="utf-8"/>
# <!-- Always force latest IE rendering engine or request Chrome Frame -->
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/> <title>Space Images</title>
# ...

# %%
# Retrieve the parent divs for all articles
results = soup.find_all('div', class_='carousel_items')

# %%
results
# Out:
# [<div class="carousel_items">
#  <article alt="Daybreak at Gale Crater" class="carousel_item" style="background-image: url('/spaceimages/images/wallpaper/PIA14293-1920x1200.jpg');">
#  <div class="default floating_text_area ms-layer">
#  <h2 class="category_title">
#  </h2>
#  <h2 class="brand_title">
#  				  FEATURED IMAGE
#  				</h2>
#  <h1 class="media_feature_title">
#  				  Daybreak at Gale Crater				</h1>
#  <div class="description">
#  </div>
#  <footer>
#  <a class="button fancybox" data-description="This computer-generated view depicts part of Mars at the boundary between darkness and daylight, with an area including Gale Crater beginning to catch morning light. NASA has selected Gale as the landing site for the Mars Science Laboratory mission." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/mediumsize/PIA14293_ip.jpg" data-link="/spaceimages/details.php?id=PIA14293" data-title="Daybreak at Gale Crater" id="full_image">
#  					FULL IMAGE
# ...

# %%
var bi = $('a').css("background-image");
alert(bi.split(/"/)[1]);
# Out:
#   File "<ipython-input-70-56abc671f0a1>", line 1
#     var bi = $('a').css("background-image");
#          ^
# SyntaxError: invalid syntax

# %%
featured_image_url = document.getElementById('full_image').style.background-image.url;
featured_image_url
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-eb6ea09f8e00> in <module>()
# ----> 1 featured_image_url = document.getElementById('full_image').style.background-image.url;
#       2 featured_image_url
#
# NameError: name 'document' is not defined

# %%
featured_image_url = soup.find("article", class_="sc-carousel_item")['style']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-e33afe470ca4> in <module>()
# ----> 1 featured_image_url = soup.find("article", class_="sc-carousel_item")['style']
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# image_info.append((image_tag[0]["src"], image_tag[0]["alt"]))

image_info = []

for a in results:
    image_tag = a.findChildren("img")
    image_info((image_tag[0]["src"], image_tag[0]["alt"]))
    
print(image_info)
# Out:
# []

# %%
results = soup.find_all('article', class_='background-image: url')

# %%
results
# Out:
# []

# %%
# loop over results to get featured image
for result in results:
    # scrape the article header 
    featured_image_url = result.find('div','carousel_items', 'url').text
 
        # print article data
    print('-----------------')
    print(featured_image_url)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-5a6a46bf4831> in <module>()
#       2 for result in results:
#       3     # scrape the article header
# ----> 4     featured_image_url = result.find('div','carousel_items', 'url').text
#       5
#       6         # print article data
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
# Scrape the browser into soup and use soup to find the full resolution image of mars
# Save the image url to a variable called `img_url`
# img_url = soup.find("img", class_="jpg")["src"]
# img_url

img_url = soup.find(class_="a")["data-link"]
img_url
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-febc39344c37> in <module>()
#       4 # img_url
#       5
# ----> 6 img_url = soup.find(class_="a")["data-link"]
#       7 img_url
#
# TypeError: 'NoneType' object is not subscriptable

# %%
browser.quit()
